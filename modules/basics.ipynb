# %%
import numpy as ap
ap.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from packages.maths import addition
addition(2,3)
# Out:
# 5

# %%
from packages  import maths

addition(3,4)
# Out:
# 7

# %%
import os
print(os.getcwd())
# Out:
# /Users/ujjwalsinha/Desktop/python/modules

# %%
import json
name ={'name':'ujjwal'}
json_wrt= json.dumps(name)
print(json_wrt)
print(type(json_wrt))

parsed_data=json.loads(json_wrt)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "ujjwal"}
# <class 'str'>
# {'name': 'ujjwal'}
# <class 'dict'>

# %%
import csv
with open ('example.csv', mode='w',newline='')as file:
    writer= csv.writer(file)
    writer.writerow(["name","age"])
    writer.writerow(["ujjwal","21"])
    
    
with open ('example.csv', mode='r',)as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['ujjwal', '21']
