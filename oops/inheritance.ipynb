# %%
class Car:
    def __init__(self,window, door):
        self.window=window
        self.door=door
     
    def drive(self):
        print("it will")
        
        
        
        
car= Car(4,2)
print(car.drive)
# Out:
# <bound method Car.drive of <__main__.Car object at 0x10647a990>>

# %%
class Tesla(Car):
    def __init__(self, window, door,is_selfdriven):
        super().__init__(window, door)
        self.is_selffriven=is_selffriven
