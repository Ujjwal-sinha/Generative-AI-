# %%
import pandas as pd
message=pd.read_csv('file.csv',sep="\t",names=["label", "message"])

message
# Out:
#                                                label  message
# 0  Beans. I was trying to explain to somebody as ...      NaN
# 1  And they were very impressed at my agricultura...      NaN
# 2  I have a bunch of good friends here today, inc...      NaN
# 3  your Senator, Dick Durbin is here. I also noti...      NaN
# 4  And it’s great to see you, Governor. I want to...      NaN
# 5  I am deeply honored at the Paul Douglas Award ...      NaN
# 6  Now, I want to start by addressing the elephan...      NaN
