# %%
corpus=""" hello i am ujjwal sinha  i am a good boy and i am a ml developer """

print (corpus)
# Out:
#  hello i am ujjwal sinha  i am a good boy and i am a ml developer

# %%
## sentence to paragraph 

from nltk.tokenize import sent_tokenize



sent_tokenize(corpus)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 3
#       1 ## sentence to paragraph
# ----> 3 from nltk.tokenize import sent_tokenize
#       7 sent_tokenize(corpus)
#
# ModuleNotFoundError: No module named 'nltk'

# %%
from nltk.tokenize import word_tokenize
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from nltk.tokenize import word_tokenize
#
# ModuleNotFoundError: No module named 'nltk'

# %%
words=["eating ", "eaten ", "finally"]

from nltk.stem import PorterStemmer
stemming = PorterStemmer()
for word in words:
    print(word+ "--->"+stemming.stem(word))
# Out:
# eating --->eating
# eaten --->eaten
# finally--->final
