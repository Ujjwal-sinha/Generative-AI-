# %%
with open ('example.txt','r')as file:
    content= file.read()
    print(content)
# Out:
# how
# hwllo
# ujjwal sinha
# ujju

# %%
with open('example.txt','w') as file:
    file.write("hekko")

# %%
with open('example.txt','a') as file:
    file.write("hekkofbfbjfjf/n")

# %%
with open('example.txt','w+') as file:
     file.write("hekkofbfbjfjf/n")
     file.write("lauhhda")
     
     
     
     
     
     file.seek(0)
